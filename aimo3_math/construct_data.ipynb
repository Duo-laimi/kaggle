# %%
from datapre.openr1_math import FormattedOpenr1Math
from transformers import AutoTokenizer

model_path = "/mnt/workspace/model/qwen3-8b"
tokenizer = AutoTokenizer.from_pretrained(model_path)

data_path = "/mnt/workspace/dataset/OpenR1-Math-220k"

openr1_sampler = FormattedOpenr1Math(data_path, tokenizer, remove_unused=True)
sampled_ds = openr1_sampler.sample(3500)
